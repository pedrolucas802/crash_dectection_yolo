# %%
import matplotlib.pyplot as plt

# Data extracted from the provided logs
epochs = list(range(10))
box_loss = [0.09482, 0.06678, 0.05925, 0.05277, 0.04914, 0.0458, 0.04158, 0.03826, 0.03559, 0.03328]
obj_loss = [0.02862, 0.02956, 0.02751, 0.02535, 0.02308, 0.02095, 0.01877, 0.01763, 0.01661, 0.01637]
cls_loss = [0.02812, 0.02577, 0.02441, 0.02108, 0.01711, 0.01405, 0.01394, 0.01079, 0.01, 0.009947]
map50 = [0.00658, 0.0566, 0.0631, 0.168, 0.11, 0.506, 0.59, 0.79, 0.873, 0.889]
map5095 = [0.00189, 0.0139, 0.0251, 0.0351, 0.037, 0.206, 0.257, 0.428, 0.498, 0.566]
precision = [0.00311, 0.00334, 0.0275, 0.134, 0.118, 0.443, 0.484, 0.776, 0.846, 0.824]
recall = [0.918, 0.989, 0.981, 0.575, 0.604, 0.622, 0.651, 0.676, 0.782, 0.875]

# Plotting the training metrics
plt.figure(figsize=(12, 12))

plt.subplot(3, 1, 1)
plt.plot(epochs, box_loss, label='Box Loss')
plt.plot(epochs, obj_loss, label='Object Loss')
plt.plot(epochs, cls_loss, label='Classification Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Losses')
plt.legend()

plt.subplot(3, 1, 2)
plt.plot(epochs, map50, label='mAP@50')
plt.plot(epochs, map5095, label='mAP@50-95')
plt.xlabel('Epochs')
plt.ylabel('mAP')
plt.title('Mean Average Precision (mAP)')
plt.legend()

plt.subplot(3, 1, 3)
plt.plot(epochs, precision, label='Precision')
plt.plot(epochs, recall, label='Recall')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.title('Precision and Recall')
plt.legend()

plt.tight_layout()
plt.show()
